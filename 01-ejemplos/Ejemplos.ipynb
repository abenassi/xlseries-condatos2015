# %% [markdown]
# # Ejemplos

# %% [markdown]
# Archivos excel con series de tiempo de ejemplo scrapeados con XlSeries para el taller realizado en CONDATOS 2015 en Santiago de Chile.

# %%
from xlseries import XlSeries

# %% [markdown]
# #### 1 (Chile - INE): ÍNDICE DE PRECIOS AL CONSUMIDOR (IPC) - COBERTURA NACIONAL - BASE AÑO 2009 - HOJA DE CIFRA GENERALES

# %%
xl1 = XlSeries("ipc_general_referencial_diciembre2013.xlsx")

# %%
params1 = {
    "headers_coord": "D5-G5",
    "frequency": "M",
    "time_header_coord": "B5-C5",
    "data_starts": 6
}

# %%
df1 = xl1.get_data_frames(params1)

# %%
df1.tail()
# Out:
#          Indice  Variacion Mensual  Variacion Acumulada  Variacion a 12 Meses
# 2013-08  110.06                0.2                  1.3                   2.2
# 2013-09  110.65                0.5                  1.9                   2.0
# 2013-10  110.80                0.1                  2.0                   1.5
# 2013-11  111.22                0.4                  2.4                   2.4
# 2013-12  111.88                0.6                  3.0                   3.0

# %% [markdown]
# #### 2 (Chile - INE): INDICE GENERAL DE REMUNERACIONES Y DE COSTO DE LA MANO DE OBRA POR HORA - (Base Enero 2006=100)

# %%
xl2 = XlSeries("01-ejemplos/serie12101.xls")

# %%
params2 = {
    "headers_coord": ["C5", "D6-F6", "G5", "H6-J6"],
    "frequency": "M",
    "time_header_coord": "A5-B5",
    "data_starts": 8,
    "context": {
        "Indice Nominal de Remuneraciones": "C4-F4",
        "Indice Nominal de Costo Mano de Obra": "G4-J4",
        "Variacion": ["D5-F5", "H5-J5"]
    }
}

# %%
df2 = xl2.get_data_frames(params2)

# %%
df2.tail()
# Out:
#          Indice Nominal de Remuneraciones - Indice  \
# 2009-08                                     127.17
# 2009-09                                     127.85
# 2009-10                                     128.12
# 2009-11                                     128.51
# 2009-12                                     129.88
#
#          Indice Nominal de Remuneraciones - Variacion - Mes Anterior  \
# 2009-08                                                0.4
# 2009-09                                                0.5
# 2009-10                                                0.2
# 2009-11                                                0.3
# 2009-12                                                1.1
#
#          Indice Nominal de Remuneraciones - Variacion - Respecto Diciembre  \
# 2009-08                                                2.8
# 2009-09                                                3.3
# 2009-10                                                3.5
# 2009-11                                                3.9
# 2009-12                                                5.0
#
#          Indice Nominal de Remuneraciones - Variacion - En 12 Meses  \
# 2009-08                                                5.9
# 2009-09                                                5.7
# 2009-10                                                5.5
# 2009-11                                                5.4
# 2009-12                                                5.0
#
#          Indice Nominal de Costo Mano de Obra - Indice  \
# 2009-08                                         123.99
# 2009-09                                         124.70
# 2009-10                                         124.98
# 2009-11                                         125.32
# 2009-12                                         126.80
#
#          Indice Nominal de Costo Mano de Obra - Variacion - Mes Anterior  \
# 2009-08                                                0.4
# 2009-09                                                0.6
# 2009-10                                                0.2
# 2009-11                                                0.3
# 2009-12                                                1.2
#
#          Indice Nominal de Costo Mano de Obra - Variacion - Respecto Diciembre  \
# 2009-08                                                3.0
# 2009-09                                                3.6
# 2009-10                                                3.8
# 2009-11                                                4.1
# 2009-12                                                5.3
#
#          Indice Nominal de Costo Mano de Obra - Variacion - En 12 Meses
# 2009-08                                                6.7
# 2009-09                                                6.5
# 2009-10                                                6.2
# 2009-11                                                6.0
# 2009-12                                                5.3

# %% [markdown]
# #### 3 (Chile - INE): POBLACIÓN, PAÍS Y REGIONES: ACTUALIZACIÓN POBLACIÓN 2002-2012 Y PROYECCIONES 2013-2020

# %%
xl3 = XlSeries("proyecciones-de-poblacion-2014.xlsx")

# %%
params3_ambos_sexos = {
    "headers_coord": "A6-A87",
    "frequency": "Y",
    "time_header_coord": "A5",
    "data_starts": 2
}

params3_hombres = params3_ambos_sexos.copy()
params3_hombres["headers_coord"] = "A92-A173"
params3_hombres["time_header_coord"] = "A91"

params3_mujeres = params3_ambos_sexos.copy()
params3_mujeres["headers_coord"] = "A178-A259"
params3_mujeres["time_header_coord"] = "A177"

# %%
ws_name = "País"

# %%
df3_ambos_sexos = xl3.get_data_frames(params3_ambos_sexos, ws_name)
df3_hombres = xl3.get_data_frames(params3_hombres, ws_name)
df3_mujeres = xl3.get_data_frames(params3_mujeres, ws_name)

# %%
df3_ambos_sexos.tail()
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 2016  249552  249221  247411  245296  246480  250650  253299  251535  245995
# 2017  248757  249979  249731  247943  245836  246986  251119  253768  252012
# 2018  247753  249181  250496  250264  248486  246341  247458  251591  254245
# 2019  246560  248189  249694  251033  250808  248994  246809  247935  252069
# 2020  245194  246996  248709  250230  251583  251312  249467  247285  248415
#
#            9    ...         72      73      74     75     76     77     78  \
# 2016  239252    ...     101888   95151   88365  81972  75978  70607  65681
# 2017  246464    ...     106098   99430   92549  85691  79252  73180  67778
# 2018  252484    ...     109790  103550   96724  89764  82860  76336  70258
# 2019  254713    ...     113307  107172  100748  93829  86804  79820  73301
# 2020  252542    ...     116985  110623  104284  97746  90743  83632  76656
#
#          79  80 o mas     Total
# 2016  60933    400616  18191884
# 2017  62880    417001  18373917
# 2018  64891    433871  18552218
# 2019  67275    451266  18726548
# 2020  70202    469536  18896684
#
# [5 rows x 82 columns]

# %%
df3_hombres.tail()
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 2016  127015  126836  125910  124822  125705  127833  128955  128179  125450
# 2017  126615  127221  127090  126173  125086  125949  128057  129179  128409
# 2018  126109  126821  127476  127355  126439  125330  126174  128284  129408
# 2019  125505  126322  127077  127740  127621  126684  125554  126405  128512
# 2020  124813  125718  126582  127342  128009  127865  126912  125781  126637
#
#            9   ...        72     73     74     75     76     77     78     79  \
# 2016  122021   ...     46090  42614  39186  35925  32831  30045  27480  25015
# 2017  125674   ...     48115  44669  41137  37669  34390  31280  28503  25976
# 2018  128635   ...     49927  46643  43132  39556  36068  32770  29684  26948
# 2019  129633   ...     51676  48413  45048  41488  37881  34377  31108  28074
# 2020  128738   ...     53573  50123  46768  43340  39740  36116  32641  29432
#
#       80 o mas    Total
# 2016    140728  9003254
# 2017    147355  9092950
# 2018    154401  9180864
# 2019    161843  9266854
# 2020    169800  9350786
#
# [5 rows x 82 columns]

# %%
df3_mujeres.tail()
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 2016  122537  122385  121501  120474  120775  122817  124344  123356  120545
# 2017  122142  122758  122641  121770  120750  121037  123062  124589  123603
# 2018  121644  122360  123020  122909  122047  121011  121284  123307  124837
# 2019  121055  121867  122617  123293  123187  122310  121255  121530  123557
# 2020  120381  121278  122127  122888  123574  123447  122555  121504  121778
#
#            9   ...        72     73     74     75     76     77     78     79  \
# 2016  117231   ...     55798  52537  49179  46047  43147  40562  38201  35918
# 2017  120790   ...     57983  54761  51412  48022  44862  41900  39275  36904
# 2018  123849   ...     59863  56907  53592  50208  46792  43566  40574  37943
# 2019  125080   ...     61631  58759  55700  52341  48923  45443  42193  39201
# 2020  123804   ...     63412  60500  57516  54406  51003  47516  44015  40770
#
#       80 o mas    Total
# 2016    259888  9188630
# 2017    269646  9280967
# 2018    279470  9371354
# 2019    289423  9459694
# 2020    299736  9545898
#
# [5 rows x 82 columns]

# %%
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')

# %%
import pandas as pd

# %%
data = {"Ambos": df3_ambos_sexos["Total"], "Hombres": df3_hombres["Total"], "Mujeres": df3_mujeres["Total"]}
df3 = pd.DataFrame(data=data)

# %%
df3[["Hombres", "Mujeres"]].plot()

# %%
df3.iloc[-6:]
# Out:
#          Ambos  Hombres  Mujeres
# 2015  18006407  8911940  9094467
# 2016  18191884  9003254  9188630
# 2017  18373917  9092950  9280967
# 2018  18552218  9180864  9371354
# 2019  18726548  9266854  9459694
# 2020  18896684  9350786  9545898

# %% [markdown]
# #### 4 (Chile - BCC): Balanza de Pagos de Chile

# %%
xl4 = XlSeries("Balanza_de_Pagos.xls")

# %%
params4 = {
    "headers_coord": ["A9_B9", "C11", "E12", "G13-G14",
                      "E15", "G16-G17", "C18", "E19",
                      "F20", "H21-H22", "F23", "G24-G25",
                      "F26", "G27-G28", "C29", "F30-F31",
                      "A34", "A36", "A38", "E40", "G41",
                      "H42-H44", "G45", "H46-H48", "E49",
                      "G50-G51", "E52-E53", "G54", "H55-H58",
                      "G59", "H60-H64", "E65", "A67", "B73"],
    "frequency": "QQQQY",
    "time_header_coord": ["H5", "H7"],
    "data_starts": 9,
    "context": {
        "I. Cuenta corriente": "A10-A31",
        "A. Bienes y servicios": "C12-C17",
        "Bienes": "E13-E14",
        "Servicios": "E16-E17",
        "B. Renta (Ingreso primario)": "C19-C28",
        "Renta de la inversión": "E20-E28",
        "C.  Transferencias corrientes (Ingreso secundario)": "C30-C31",
        "IV. Cuenta financiera (2)": "A39-A65",
        "A.  Inversión directa": "E41-E48",
        "Activos": ["G42-G44", "G55-G58"],
        "Pasivos": ["G46-G48", "G60-G64"],
        "B. Inversión de cartera": "E50-E51",
        "D. Otra inversión": "E54-E64"
    },
}

# %%
df4 = xl4.get_data_frames(params4)

# %%
print "Now there is", len(df4), "dataframes."
# Out:
# Now there is 2 dataframes.

# %%
print "A quarterly one..."
df4[0].tail()
# Out:
# A quarterly one...
#         I. Cuenta corriente  I. Cuenta corriente - A. Bienes y servicios  \
# 2014Q2          -251.052853                                  1898.408460
# 2014Q3         -1584.242533                                    32.350798
# 2014Q4          -704.809399                                   672.626967
# 2015Q1          1220.564403                                  1847.492343
# 2015Q2           761.060663                                  1801.818552
#
#         I. Cuenta corriente - A. Bienes y servicios - Bienes  \
# 2014Q2                                        2853.255732
# 2014Q3                                        1055.212979
# 2014Q4                                        1743.054357
# 2015Q1                                        2580.000000
# 2015Q2                                        2905.000000
#
#         I. Cuenta corriente - A. Bienes y servicios - Bienes - Exportaciones  \
# 2014Q2                                       19627.694230
# 2014Q3                                       18060.564608
# 2014Q4                                       18948.496023
# 2015Q1                                       17270.000000
# 2015Q2                                       16677.000000
#
#         I. Cuenta corriente - A. Bienes y servicios - Bienes - Importaciones  \
# 2014Q2                                       16774.438497
# 2014Q3                                       17005.351629
# 2014Q4                                       17205.441666
# 2015Q1                                       14690.000000
# 2015Q2                                       13772.000000
#
#         I. Cuenta corriente - A. Bienes y servicios - Servicios  \
# 2014Q2                                        -954.847272
# 2014Q3                                       -1022.862181
# 2014Q4                                       -1070.427390
# 2015Q1                                        -732.507657
# 2015Q2                                       -1103.181448
#
#         I. Cuenta corriente - A. Bienes y servicios - Servicios - Exportaciones  \
# 2014Q2                                        2870.812696
# 2014Q3                                        2389.842663
# 2014Q4                                        2576.944428
# 2015Q1                                        2693.434607
# 2015Q2                                        2374.161171
#
#         I. Cuenta corriente - A. Bienes y servicios - Servicios - Importaciones  \
# 2014Q2                                        3825.659968
# 2014Q3                                        3412.704844
# 2014Q4                                        3647.371818
# 2015Q1                                        3425.942264
# 2015Q2                                        3477.342619
#
#         I. Cuenta corriente - B. Renta ( Ingreso primario)  \
# 2014Q2                                       -2699.317654
# 2014Q3                                       -2144.325933
# 2014Q4                                       -1666.362791
# 2015Q1                                       -1080.013037
# 2015Q2                                       -1434.955046
#
#         I. Cuenta corriente - B. Renta (Ingreso primario) - Renta de la inversion  \
# 2014Q2                                       -2662.732266
# 2014Q3                                       -2110.253882
# 2014Q4                                       -1633.471779
# 2015Q1                                       -1047.176833
# 2015Q2                                       -1402.122229
#
#                              ...                         \
# 2014Q2                       ...
# 2014Q3                       ...
# 2014Q4                       ...
# 2015Q1                       ...
# 2015Q2                       ...
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Activos - Otros activos  \
# 2014Q2                                                  0
# 2014Q3                                                  0
# 2014Q4                                                  0
# 2015Q1                                                  0
# 2015Q2                                                  0
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos  \
# 2014Q2                                        -599.428200
# 2014Q3                                       -2307.601968
# 2014Q4                                        -105.260830
# 2015Q1                                       -2529.599816
# 2015Q2                                        -798.969461
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Creditos comerciales  \
# 2014Q2                                        -616.388514
# 2014Q3                                        -273.897500
# 2014Q4                                         238.630559
# 2015Q1                                        -767.428844
# 2015Q2                                        -386.881971
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Prestamos  \
# 2014Q2                                        -100.157816
# 2014Q3                                       -1876.818568
# 2014Q4                                        -434.233193
# 2015Q1                                       -1973.171691
# 2015Q2                                        -550.671673
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Monedas y depositos  \
# 2014Q2                                         116.751437
# 2014Q3                                        -154.417926
# 2014Q4                                          78.806499
# 2015Q1                                         223.918660
# 2015Q2                                         139.152976
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Otros pasivos  \
# 2014Q2                                           0.405742
# 2014Q3                                          -2.383181
# 2014Q4                                          11.558315
# 2015Q1                                         -12.909924
# 2015Q2                                          -0.573717
#
#         IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Asignaciones  DEG  \
# 2014Q2                                          -0.039050
# 2014Q3                                          -0.084792
# 2014Q4                                          -0.023010
# 2015Q1                                          -0.008017
# 2015Q2                                           0.004924
#
#         IV. Cuenta financiera (2) - E. Activos de reserva           V.  \
# 2014Q2                                        -110.063525   292.974315
# 2014Q3                                         179.648129  -789.840026
# 2014Q4                                        1121.735292  -386.323575
# 2015Q1                                        -604.672409   868.295276
# 2015Q2                                        -289.326085 -1357.626017
#
#         Cuenta financiera excluyendo activos de reserva
# 2014Q2                                       154.031044
# 2014Q3                                     -2551.173263
# 2014Q4                                     -2210.068274
# 2015Q1                                      2759.686318
# 2015Q2                                      -305.882180
#
# [5 rows x 53 columns]

# %%
print "...and a yearly one"
df4[1].tail()
# Out:
# ...and a yearly one
#       I. Cuenta corriente  I. Cuenta corriente - A. Bienes y servicios  \
# 2010          3769.145711                                 14044.511329
# 2011         -3087.887039                                  7967.007774
# 2012         -9624.397580                                  -410.908340
# 2013        -10125.042079                                 -1582.054537
# 2014         -2995.465054                                  4010.421787
#
#       I. Cuenta corriente - A. Bienes y servicios - Bienes  \
# 2010                                       15941.467587
# 2011                                       11039.627181
# 2012                                        2332.912353
# 2013                                        1820.432021
# 2014                                        7767.089448
#
#       I. Cuenta corriente - A. Bienes y servicios - Bienes - Exportaciones  \
# 2010                                       71108.528875
# 2011                                       81437.843854
# 2012                                       77790.647635
# 2013                                       76477.000265
# 2014                                       75674.847293
#
#       I. Cuenta corriente - A. Bienes y servicios - Bienes - Importaciones  \
# 2010                                       55167.061288
# 2011                                       70398.216673
# 2012                                       75457.735282
# 2013                                       74656.568244
# 2014                                       67907.757845
#
#       I. Cuenta corriente - A. Bienes y servicios - Servicios  \
# 2010                                       -1896.956258
# 2011                                       -3072.619407
# 2012                                       -2743.820693
# 2013                                       -3402.486558
# 2014                                       -3756.667661
#
#       I. Cuenta corriente - A. Bienes y servicios - Servicios - Exportaciones  \
# 2010                                       11148.734554
# 2011                                       13105.282107
# 2012                                       12386.862287
# 2013                                       12452.156583
# 2014                                       10967.031432
#
#       I. Cuenta corriente - A. Bienes y servicios - Servicios - Importaciones  \
# 2010                                       13045.690812
# 2011                                       16177.901514
# 2012                                       15130.682980
# 2013                                       15854.643141
# 2014                                       14723.699093
#
#       I. Cuenta corriente - B. Renta ( Ingreso primario)  \
# 2010                                      -14685.755912
# 2011                                      -13919.734818
# 2012                                      -11273.623626
# 2013                                      -10730.386527
# 2014                                       -8857.254062
#
#       I. Cuenta corriente - B. Renta (Ingreso primario) - Renta de la inversion  \
# 2010                                      -14684.155912
# 2011                                      -13921.134818
# 2012                                      -11219.102272
# 2013                                      -10559.154674
# 2014                                       -8713.501592
#
#                            ...                         \
# 2010                       ...
# 2011                       ...
# 2012                       ...
# 2013                       ...
# 2014                       ...
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Activos - Otros activos  \
# 2010                                        3487.000000
# 2011                                       -1684.000000
# 2012                                       -1242.269788
# 2013                                        -539.149502
# 2014                                           0.000000
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos  \
# 2010                                        1746.380870
# 2011                                        5043.295879
# 2012                                        2679.263838
# 2013                                       -2449.225403
# 2014                                       -3873.026407
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Creditos comerciales  \
# 2010                                        1701.148759
# 2011                                        1582.661148
# 2012                                        -316.261355
# 2013                                        -639.066433
# 2014                                       -1512.497964
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Prestamos  \
# 2010                                        -272.604089
# 2011                                        3566.434731
# 2012                                        2363.754879
# 2013                                       -1726.759596
# 2014                                       -2260.995208
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Monedas y depositos  \
# 2010                                         320.000000
# 2011                                        -117.500000
# 2012                                         618.216751
# 2013                                         -64.601169
# 2014                                        -104.125379
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Otros pasivos  \
# 2010                                          -2.400000
# 2011                                          11.900000
# 2012                                          13.622143
# 2013                                         -18.798205
# 2014                                           4.706052
#
#       IV. Cuenta financiera (2) - D. Otra inversión - Pasivos - Asignaciones  DEG  \
# 2010                                           0.236200
# 2011                                          -0.200000
# 2012                                          -0.068580
# 2013                                          -0.000001
# 2014                                          -0.113907
#
#       IV. Cuenta financiera (2) - E. Activos de reserva           V.  \
# 2010                                        3023.832989 -1042.966325
# 2011                                       14190.095453  -561.848026
# 2012                                        -366.787968   291.460750
# 2013                                         311.415262 -1137.904052
# 2014                                        1056.855068   258.961493
#
#       Cuenta financiera excluyendo activos de reserva
# 2010                                      5942.818768
# 2011                                    -17827.928003
# 2012                                     -8954.417025
# 2013                                    -11562.961393
# 2014                                     -3783.123151
#
# [5 rows x 53 columns]

# %%
bp_trimestral = df4[0]

# %%
bp_trimestral[["I. Cuenta corriente", 
               "I. Cuenta corriente - A. Bienes y servicios", 
               "I. Cuenta corriente - B. Renta ( Ingreso primario)", 
               "I. Cuenta corriente - C.  Transferencias corrientes (Ingreso secundario)"]].plot(figsize=(15, 7))

# %% [markdown]
# #### 5 (Argentina - BCRA): Tipo de cambio Argentina (test case 2)

# %% [markdown]
# El excel del cual fue tomado este caso de testeo ya no se publica como tal, en su lugar hay una aplicación web que muestra el resultado en html.

# %%
from xlseries.utils.path_finders import get_orig_cases_path

# %%
xl5 = XlSeries(get_orig_cases_path(2))

# %%
params5 = {'blank_rows': [False, True],
           'continuity': [True, False],
           'data_starts': [5, 22],
           'frequency': [u'D', u'M'],
           'headers_coord': [u'D4', u'F4'],
           'missing_value': [u'Implicit', None],
           'missings': [True, False],
           'time_alignment': [0, -1],
           'time_header_coord': [u'C4', u'F4'],
           }

# %%
df5 = xl5.get_data_frames(params5)

# %%
df5[0].tail()
# Out:
#             Tipo de Cambio de Referencia - en Pesos - por Dolar
# 2014-04-06                                                NaN
# 2014-04-07                                             8.0018
# 2014-04-08                                             8.0013
# 2014-04-09                                             8.0008
# 2014-04-10                                             8.0012

# %%
df5[1].tail()
# Out:
#          Tipo de Cambio Nominal Promedio Mensual
# 2013-11                                 6.014937
# 2013-12                                 6.319179
# 2014-01                                 7.096727
# 2014-02                                 7.856530
# 2014-03                                 7.931300
